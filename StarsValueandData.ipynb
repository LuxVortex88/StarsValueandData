# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {"Stars": ['Daryl', 'Gea', 'Eddard','Doux']}

value = [100, 400, 500, 100]
print(data)
print(value)


plt.bar(data["Stars"], value)
plt.xlabel("Stars")
plt.ylabel("Value")

plt.title("Stars vs Value")
plt.show()
# Out:
# {'Stars': ['Daryl', 'Gea', 'Eddard', 'Doux']}
# [100, 400, 500, 100]
